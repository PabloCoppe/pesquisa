# %% [markdown]
# **Zeros de Funções Reais**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Como obter raízes reais de uma equação qualquer?**
#
# **Fase I:** Localização ou isomalento das raízes, que consiste em obter um intervalo que contém a raiz;
#
# **Fase II:** Refinamento, que consiste em, escolhidas aproxiamções iniciais no intervalos encontrado na Fase I, melhorá-lás sucesivamente até se obter uma aproximação dentro de uma precissão "e" préfixada.

# %% [markdown]
# **Isolamento de raízes**
#
# Teorema I : Teorema de Bolzano

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
